# %%
import numpy as np
import pandas as pd
import seaborn as sns

subspace_num = [1, 2, 4, 8, 16, 32, 0]
C3_untruthfulness = np.zeros((7,7))
C2_untruthfulness = np.zeros((7,7))
C1_untruthfulness = np.zeros((7,7))
C3_untruthfulness_harmonica = np.zeros((4,7))
C2_untruthfulness_harmonica = np.zeros((4,7))
C1_untruthfulness_harmonica = np.zeros((4,7))

# C_range = [1, 2, 3]
# for C in C_range:
#     for subspace_limit in [0, 1, 2, 4, 8, 16, 32]:
#         exec(f"final_truthful_answer_C_{C}_subspace_{subspace_limit} = []")

# np.save(
#     f"harmonicalocal2degree/harmonicalocal2degree_truthful_answer_C_{C}_subspace_{subspace_limit}_seed{args.seed}_{args.split_start}_{args.split_end}",
#     eval(f"final_truthful_answer_C_{C}_subspace_{subspace_limit}"))

# %%
# !pwd
# Out:
# /home/hehaowei/h0sda/truthful-interpretability/Movie_Review/IMDB

# %%
print("Harmonica 2 order")
degree = 2
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./harmonica2degree/harmonica2degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 5500, 7000, 8500, 10000, 11250, 12500, 13750, 15000, 16250, 17500, 18750, 20000, 21250, 22500, 23750], 
                                          [1000, 1500, 2000, 2500, 3000, 3500, 4000, 5500, 7000, 8500, 10000, 11250, 12500, 13750, 15000, 16250, 17500, 18750, 20000, 21250, 22500, 23750, 25000]):
            temp_answer_output = np.load(f"./harmonica2degree/harmonica2degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        print(final_answer_output.shape)
        untruthfulness = 0

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness_harmonica")[0][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        eval(f"C{C}_untruthfulness")[0][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        idx += 1
# Out:
# Harmonica 2 order
# C = 1
# (24741,)
# subspace 1
# Untruthfulness 0.0002
# (24741,)
# subspace 2
# Untruthfulness 0.0001
# (24741,)
# subspace 4
# Untruthfulness 0.0001
# (24741,)
# subspace 8
# Untruthfulness 0.0001
# (24741,)
# subspace 16
# Untruthfulness 0.0001
# (24741,)
# subspace 32
# Untruthfulness 0.0001
# (24741,)
# subspace infinity
# Untruthfulness 0.0001
# C = 2
# (24741,)
# subspace 1
# Untruthfulness 0.0002
# (24741,)
# subspace 2
# Untruthfulness 0.0001
# (24741,)
# subspace 4
# Untruthfulness 0.0
# (24741,)
# subspace 8
# Untruthfulness 0.0
# (24741,)
# subspace 16
# Untruthfulness 0.0
# (24741,)
# subspace 32
# Untruthfulness 0.0
# (24741,)
# subspace infinity
# Untruthfulness 0.0
# C = 3
# (24741,)
# subspace 1
# Untruthfulness 0.0002
# (24741,)
# subspace 2
# Untruthfulness 0.0001
# (24741,)
# subspace 4
# Untruthfulness 0.0001
# (24741,)
# subspace 8
# Untruthfulness 0.0001
# (24741,)
# subspace 16
# Untruthfulness 0.0001
# (24741,)
# subspace 32
# ...

# %%
print("Harmonica 3 order")
degree = 3
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./harmonica3degree/harmonica3degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21250, 22500, 23750], 
                                          [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21250, 22500, 23750, 25000]):
            temp_answer_output = np.load(f"./harmonica3degree/harmonica3degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        untruthfulness = 0
        print(final_answer_output.shape)

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness_harmonica")[1][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        eval(f"C{C}_untruthfulness")[1][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        idx += 1
# Out:
# Harmonica 3 order
# C = 1
# (24248,)
# subspace 1
# Untruthfulness 0.0002
# (24248,)
# subspace 2
# Untruthfulness 0.0001
# (24248,)
# subspace 4
# Untruthfulness 0.0001
# (24248,)
# subspace 8
# Untruthfulness 0.0001
# (24248,)
# subspace 16
# Untruthfulness 0.0001
# (24248,)
# subspace 32
# Untruthfulness 0.0001
# (24248,)
# subspace infinity
# Untruthfulness 0.0001
# C = 2
# (24248,)
# subspace 1
# Untruthfulness 0.0001
# (24248,)
# subspace 2
# Untruthfulness 0.0001
# (24248,)
# subspace 4
# Untruthfulness 0.0
# (24248,)
# subspace 8
# Untruthfulness 0.0
# (24248,)
# subspace 16
# Untruthfulness 0.0
# (24248,)
# subspace 32
# Untruthfulness 0.0
# (24248,)
# subspace infinity
# Untruthfulness 0.0
# C = 3
# (24248,)
# subspace 1
# Untruthfulness 0.0001
# (24248,)
# subspace 2
# Untruthfulness 0.0
# (24248,)
# subspace 4
# Untruthfulness 0.0
# (24248,)
# subspace 8
# Untruthfulness 0.0
# (24248,)
# subspace 16
# Untruthfulness 0.0
# (24248,)
# subspace 32
# Untruthfulness 0.0
# ...

# %%
# print("Harmonica-local 2 order")
# degree = 2
# idx = 0

# for C in [1,2,3]:
#     print("C =", C)
#     for each_subspace_num in subspace_num:
#         split_start = 0; split_end = 25
#         final_answer_output = np.load(f"./harmonicalocal2degree/harmonicalocal2degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
#         for split_start in [25, 50, 75, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800]:
#             if split_start in [25, 50, 75]:
#                 split_end = split_start + 25
#             elif split_start in [100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750]:
#                 split_end = split_start + 50
#             else:
#                 split_end = split_start + 72
#             temp_answer_output = np.load(f"./harmonicalocal2degree/harmonicalocal2degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
#             final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
#         untruthfulness = 0
#         print(final_answer_output.shape)

#         for _answer in final_answer_output:
#             untruthfulness += np.sum(_answer ** 2)


#         if (each_subspace_num == 0):
#             print(f"subspace infinity")
#         else:
#             print(f"subspace {each_subspace_num}")
        
#         print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
#         eval(f"C{C}_untruthfulness_harmonica")[2][subspace_num.index(each_subspace_num)] = np.round(untruthfulness / len(final_answer_output), 4)
        
#         idx += 1

# %%
# print("Harmonica-local 3 order")
# degree = 3
# idx = 0

# for C in [1,2,3]:
#     print("C =", C)
#     for each_subspace_num in subspace_num:
#         split_start = 0; split_end = 25
#         final_answer_output = np.load(f"./harmonicalocal3degree/harmonicalocal3degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
#         for split_start in [25, 50, 75, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800]:
#             if split_start in [25, 50, 75]:
#                 split_end = split_start + 25
#             elif split_start in [100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750]:
#                 split_end = split_start + 50
#             else:
#                 split_end = split_start + 72
#             temp_answer_output = np.load(f"./harmonicalocal3degree/harmonicalocal3degree_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
#             final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
#         untruthfulness = 0
#         print(final_answer_output.shape)

#         for _answer in final_answer_output:
#             untruthfulness += np.sum(_answer ** 2)


#         if (each_subspace_num == 0):
#             print(f"subspace infinity")
#         else:
#             print(f"subspace {each_subspace_num}")
        
#         print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
#         eval(f"C{C}_untruthfulness_harmonica")[3][subspace_num.index(each_subspace_num)] = np.round(untruthfulness / len(final_answer_output), 4)
        
#         idx += 1

# %%
print("\nLIME")
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./lime/lime_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 7000, 8000, 9000, 10000, 12000, 14000, 16000, 18000, 19750, 21500, 23250], 
                                          [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 7000, 8000, 9000, 10000, 12000, 14000, 16000, 18000, 19750, 21500, 23250, 25000]):
            temp_answer_output = np.load(f"./lime/lime_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        untruthfulness = 0
        print(final_answer_output.shape)

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness")[2][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        
        idx += 1
# Out:
# LIME
# C = 1
# (25000,)
# subspace 1
# Untruthfulness 0.0025
# (25000,)
# subspace 2
# Untruthfulness 0.002
# (25000,)
# subspace 4
# Untruthfulness 0.0016
# (25000,)
# subspace 8
# Untruthfulness 0.0014
# (25000,)
# subspace 16
# Untruthfulness 0.0014
# (25000,)
# subspace 32
# Untruthfulness 0.0014
# (25000,)
# subspace infinity
# Untruthfulness 0.0014
# C = 2
# (25000,)
# subspace 1
# Untruthfulness 0.0018
# (25000,)
# subspace 2
# Untruthfulness 0.0012
# (25000,)
# subspace 4
# Untruthfulness 0.0009
# (25000,)
# subspace 8
# Untruthfulness 0.0008
# (25000,)
# subspace 16
# Untruthfulness 0.0008
# (25000,)
# subspace 32
# Untruthfulness 0.0008
# (25000,)
# subspace infinity
# Untruthfulness 0.0008
# C = 3
# (25000,)
# subspace 1
# Untruthfulness 0.0014
# (25000,)
# subspace 2
# Untruthfulness 0.0008
# (25000,)
# subspace 4
# Untruthfulness 0.0006
# (25000,)
# subspace 8
# Untruthfulness 0.0005
# (25000,)
# subspace 16
# Untruthfulness 0.0005
# (25000,)
# subspace 32
# ...

# %%
print("\nKernelSHAP")
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./ks/ks_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000, 22000, 24000], 
                                          [1000, 1500, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000, 22000, 24000, 25000]):
            temp_answer_output = np.load(f"./ks/ks_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        untruthfulness = 0
        print(final_answer_output.shape)

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness")[3][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        
        idx += 1
# Out:
# KernelSHAP
# C = 1
# (24741,)
# subspace 1
# Untruthfulness 0.0022
# (24741,)
# subspace 2
# Untruthfulness 0.0027
# (24741,)
# subspace 4
# Untruthfulness 0.0022
# (24741,)
# subspace 8
# Untruthfulness 0.0015
# (24741,)
# subspace 16
# Untruthfulness 0.0013
# (24741,)
# subspace 32
# Untruthfulness 0.0012
# (24741,)
# subspace infinity
# Untruthfulness 0.0012
# C = 2
# (24741,)
# subspace 1
# Untruthfulness 0.0017
# (24741,)
# subspace 2
# Untruthfulness 0.0012
# (24741,)
# subspace 4
# Untruthfulness 0.0007
# (24741,)
# subspace 8
# Untruthfulness 0.0004
# (24741,)
# subspace 16
# Untruthfulness 0.0004
# (24741,)
# subspace 32
# Untruthfulness 0.0004
# (24741,)
# subspace infinity
# Untruthfulness 0.0004
# C = 3
# (24741,)
# subspace 1
# Untruthfulness 0.0014
# (24741,)
# subspace 2
# Untruthfulness 0.0006
# (24741,)
# subspace 4
# Untruthfulness 0.0002
# (24741,)
# subspace 8
# Untruthfulness 0.0001
# (24741,)
# subspace 16
# Untruthfulness 0.0001
# (24741,)
# subspace 32
# ...

# %%
print("\nIG")
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./ig/ig_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 7000, 8000, 9000, 10000, 12000, 14000, 16000, 18000, 19750, 21500, 23250], 
                                          [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 7000, 8000, 9000, 10000, 12000, 14000, 16000, 18000, 19750, 21500, 23250, 25000]):
            temp_answer_output = np.load(f"./ig/ig_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        untruthfulness = 0
        print(final_answer_output.shape)

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness")[4][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        
        idx += 1
# Out:
# IG
# C = 1
# (25000,)
# subspace 1
# Untruthfulness 0.0027
# (25000,)
# subspace 2
# Untruthfulness 0.0037
# (25000,)
# subspace 4
# Untruthfulness 0.0036
# (25000,)
# subspace 8
# Untruthfulness 0.0031
# (25000,)
# subspace 16
# Untruthfulness 0.0029
# (25000,)
# subspace 32
# Untruthfulness 0.0029
# (25000,)
# subspace infinity
# Untruthfulness 0.0029
# C = 2
# (25000,)
# subspace 1
# Untruthfulness 0.0024
# (25000,)
# subspace 2
# Untruthfulness 0.002
# (25000,)
# subspace 4
# Untruthfulness 0.0011
# (25000,)
# subspace 8
# Untruthfulness 0.0005
# (25000,)
# subspace 16
# Untruthfulness 0.0004
# (25000,)
# subspace 32
# Untruthfulness 0.0004
# (25000,)
# subspace infinity
# Untruthfulness 0.0004
# C = 3
# (25000,)
# subspace 1
# Untruthfulness 0.0023
# (25000,)
# subspace 2
# Untruthfulness 0.0011
# (25000,)
# subspace 4
# Untruthfulness 0.0004
# (25000,)
# subspace 8
# Untruthfulness 0.0002
# (25000,)
# subspace 16
# Untruthfulness 0.0001
# (25000,)
# subspace 32
# ...

# %%
# C3_untruthfulness = np.zeros((7,7))
# C2_untruthfulness = np.zeros((7,7))
# C1_untruthfulness = np.zeros((7,7))
# C3_untruthfulness_harmonica = np.zeros((4,7))
# C2_untruthfulness_harmonica = np.zeros((4,7))
# C1_untruthfulness_harmonica = np.zeros((4,7))
# print(np.round(C1_untruthfulness ** 2, 4))

# %%
print("\nIH")
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./ih/ih_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000], 
                                          [1000, 1500, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000]):
            temp_answer_output = np.load(f"./ih/ih_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        untruthfulness = 0
        print(final_answer_output.shape)

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness")[5][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        
        idx += 1
# Out:
# IH
# C = 1
# (25000,)
# subspace 1
# Untruthfulness 0.003
# (25000,)
# subspace 2
# Untruthfulness 0.0043
# (25000,)
# subspace 4
# Untruthfulness 0.0049
# (25000,)
# subspace 8
# Untruthfulness 0.0047
# (25000,)
# subspace 16
# Untruthfulness 0.0046
# (25000,)
# subspace 32
# Untruthfulness 0.0045
# (25000,)
# subspace infinity
# Untruthfulness 0.0045
# C = 2
# (25000,)
# subspace 1
# Untruthfulness 0.0028
# (25000,)
# subspace 2
# Untruthfulness 0.0019
# (25000,)
# subspace 4
# Untruthfulness 0.0009
# (25000,)
# subspace 8
# Untruthfulness 0.0005
# (25000,)
# subspace 16
# Untruthfulness 0.0005
# (25000,)
# subspace 32
# Untruthfulness 0.0005
# (25000,)
# subspace infinity
# Untruthfulness 0.0005
# C = 3
# (25000,)
# subspace 1
# Untruthfulness 0.0025
# (25000,)
# subspace 2
# Untruthfulness 0.0011
# (25000,)
# subspace 4
# Untruthfulness 0.0003
# (25000,)
# subspace 8
# Untruthfulness 0.0002
# (25000,)
# subspace 16
# Untruthfulness 0.0002
# (25000,)
# subspace 32
# ...

# %%
print("\nShapley Taylor")
idx = 0

for C in [1,2,3]:
    print("C =", C)
    for each_subspace_num in subspace_num:
        split_start = 0; split_end = 500
        final_answer_output = np.load(f"./shaptaylor/shaptaylor_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
        for split_start, split_end in zip([500, 1000, 1500, 2000, 3000, 4000, 5000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000, 22000, 23000, 24000], 
                                          [1000, 1500, 2000, 3000, 4000, 5000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000, 22000, 23000, 24000, 25000]):
            temp_answer_output = np.load(f"./shaptaylor/shaptaylor_truthful_answer_C_{C}_subspace_{each_subspace_num}_seed123_{split_start}_{split_end}.npy", allow_pickle=True)
            
            final_answer_output = np.concatenate([final_answer_output, temp_answer_output], axis = 0)
        
        untruthfulness = 0
        print(final_answer_output.shape)

        for _answer in final_answer_output:
            untruthfulness += np.sum(_answer ** 2)


        if (each_subspace_num == 0):
            print(f"subspace infinity")
        else:
            print(f"subspace {each_subspace_num}")
        
        print("Untruthfulness", np.round(untruthfulness / len(final_answer_output), 4))
        
        eval(f"C{C}_untruthfulness")[6][subspace_num.index(each_subspace_num)] = untruthfulness / len(final_answer_output)
        
        idx += 1
# Out:
# Shapley Taylor
# C = 1
# (25000,)
# subspace 1
# Untruthfulness 0.0015
# (25000,)
# subspace 2
# Untruthfulness 0.0013
# (25000,)
# subspace 4
# Untruthfulness 0.0011
# (25000,)
# subspace 8
# Untruthfulness 0.001
# (25000,)
# subspace 16
# Untruthfulness 0.001
# (25000,)
# subspace 32
# Untruthfulness 0.0011
# (25000,)
# subspace infinity
# Untruthfulness 0.0011
# C = 2
# (25000,)
# subspace 1
# Untruthfulness 0.0009
# (25000,)
# subspace 2
# Untruthfulness 0.0008
# (25000,)
# subspace 4
# Untruthfulness 0.0007
# (25000,)
# subspace 8
# Untruthfulness 0.0006
# (25000,)
# subspace 16
# Untruthfulness 0.0008
# (25000,)
# subspace 32
# Untruthfulness 0.0008
# (25000,)
# subspace infinity
# Untruthfulness 0.0008
# C = 3
# (25000,)
# subspace 1
# Untruthfulness 0.0008
# (25000,)
# subspace 2
# Untruthfulness 0.0007
# (25000,)
# subspace 4
# Untruthfulness 0.0006
# (25000,)
# subspace 8
# Untruthfulness 0.0006
# (25000,)
# subspace 16
# Untruthfulness 0.0008
# (25000,)
# subspace 32
# ...

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

index = ["1","2","4","8","16","32","∞"] 

for C in [1,2,3]:
    eval(f"C{C}_untruthfulness")
    plt.figure()
    df_L2 = pd.DataFrame(eval(f"C{C}_untruthfulness").T, index, ["Harmonica (2 order)", "Harmonica (3 order)", "LIME", "SHAP", "Integrated Gradients", "Integrated Hessians", "Shapley Taylor Index (2 order)"]) 

    ax_L2 = sns.lineplot(data=df_L2, marker='X') 
    # ax_L2.set(xlabel='Subspace radius', ylabel='Readable inconsistency') 
    # ax_L2.set(yscale='log')
    # ax_L2.set(ylim=[0,1])
    fig_L2 = ax_L2.get_figure() 
    ax_L2.legend(fontsize=11)
    plt.xlabel('Subspace radius', fontsize=17)
    plt.ylabel('Truthful gap', fontsize=17)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.tight_layout()
    fig_L2.savefig(f"truthful-gap-imdb-plot-c{C}.pdf")

# %%
# import numpy as np 
# import pandas as pd 
# import seaborn as sns 
# import matplotlib.pyplot as plt

# index = ["1","2","4","8","16","32","∞"] 

# for C in [1,2,3]:
#     eval(f"C{C}_untruthfulness_harmonica")
#     plt.figure()
#     df_L2 = pd.DataFrame(eval(f"C{C}_untruthfulness_harmonica").T, index, ["Harmonica (2 order)", "Harmonica (3 order)", "Harmonica-local (2 order)", "Harmonica-local (3 order)", ]) 

#     ax_L2 = sns.lineplot(data=df_L2, marker='X') 
#     # ax_L2.set(xlabel='Subspace radius', ylabel='Readable inconsistency') 
#     # ax_L2.set(yscale='log')
#     # ax_L2.set(ylim=[0,1])
#     fig_L2 = ax_L2.get_figure() 
#     ax_L2.legend(fontsize=11)
#     # ax_L2.set(yscale='log')
#     plt.xlabel('Subspace radius', fontsize=17)
#     plt.ylabel('Readable inconsistency', fontsize=17)
#     plt.xticks(fontsize=15)
#     plt.yticks(fontsize=15)
#     plt.tight_layout()
#     # fig_L2.savefig(f"readable-inconsistency-sst2-plot-c{C}.png")

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt



for C in [1,2,3]:
    eval(f"C{C}_untruthfulness")
    # plt.figure(figsize=(8,8))
    plt.figure(figsize=(6.4, 5.2))
    plt.bar(["Harmonica\n(2 order)", "Harmonica\n(3 order)", "LIME", "SHAP", "Integrated\nGradients", "Integrated\nHessians", "Shapley Taylor\nIndex (2 order)"], 
            eval(f"C{C}_untruthfulness")[:, -1],
           color =['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2',])
    plt.xticks(rotation=45, fontsize=13)
#     # ax_L2.set(yscale='log')
    plt.ylabel('Truthful gap', fontsize=17)
    plt.yticks(fontsize=15)
    # plt.tight_layout()
    # plt.yscale('log')
    if C==1:
        plt.ticklabel_format(axis='y', style='sci', scilimits=(-3,-3))
    if C==2:
        plt.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))
    if C==3:
        plt.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))
    plt.subplots_adjust(left=None, bottom=0.26, right=None, top=None, wspace=None, hspace=None)
    plt.savefig(f"truthful-gap-imdb-plot-c{C}.pdf")
